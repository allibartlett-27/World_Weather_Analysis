# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 603

# %%
#Import the requests library. 
import requests

#Import the API Key. 
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | garowe
# Processing Record 3 of Set 1 | saldanha
# Processing Record 4 of Set 1 | saint-augustin
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | klaksvik
# Processing Record 8 of Set 1 | ardatov
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | trincomalee
# Processing Record 11 of Set 1 | sao joao da barra
# Processing Record 12 of Set 1 | chaumont
# Processing Record 13 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 1 | uvat
# Processing Record 15 of Set 1 | filingue
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | ilulissat
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | kautokeino
# Processing Record 23 of Set 1 | soubre
# Processing Record 24 of Set 1 | atikokan
# Processing Record 25 of Set 1 | asilah
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | marzuq
# Processing Record 28 of Set 1 | puerto quijarro
# Processing Record 29 of Set 1 | broome
# Processing Record 30 of Set 1 | pithapuram
# Processing Record 31 of Set 1 | san quintin
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | ribeira grande
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | kaduy
# Processing Record 36 of Set 1 | eyl
# Processing Record 37 of Set 1 | laguna
# Processing Record 38 of Set 1 | mackay
# Processing Record 39 of Set 1 | maningrida
# Processing Record 40 of Set 1 | mogadishu
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | odessa
# Processing Record 45 of Set 1 | fortuna
# Processing Record 46 of Set 1 | the valley
# Processing Record 47 of Set 1 | pangai
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | kuytun
# Processing Record 50 of Set 1 | matara
# Processing Record 1 of Set 2 | cidreira
# Processing Record 2 of Set 2 | gawler
# Processing Record 3 of Set 2 | arkhangelos
# City not found. Skipping...
# Processing Record 4 of Set 2 | ancud
# Processing Record 5 of Set 2 | saryagash
# Processing Record 6 of Set 2 | tabuk
# Processing Record 7 of Set 2 | tando jam
# Processing Record 8 of Set 2 | ambilobe
# Processing Record 9 of Set 2 | chokurdakh
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | balashov
# Processing Record 13 of Set 2 | qaanaaq
# Processing Record 14 of Set 2 | yerbogachen
# Processing Record 15 of Set 2 | thohoyandou
# Processing Record 16 of Set 2 | shache
# Processing Record 17 of Set 2 | sitka
# Processing Record 18 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | deputatskiy
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | abapo
# Processing Record 23 of Set 2 | safwah
# City not found. Skipping...
# Processing Record 24 of Set 2 | kariapatti
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | grindavik
# Processing Record 27 of Set 2 | kaitangata
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | bambous virieux
# Processing Record 30 of Set 2 | anchorage
# Processing Record 31 of Set 2 | vestmannaeyjar
# Processing Record 32 of Set 2 | dubbo
# Processing Record 33 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 2 | severo-kurilsk
# Processing Record 37 of Set 2 | bluff
# Processing Record 38 of Set 2 | pisco
# Processing Record 39 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 2 | gilgil
# City not found. Skipping...
# Processing Record 41 of Set 2 | chapais
# Processing Record 42 of Set 2 | gold coast
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | acapulco
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | tieli
# Processing Record 47 of Set 2 | kavaratti
# Processing Record 48 of Set 2 | skjervoy
# Processing Record 49 of Set 2 | feijo
# Processing Record 50 of Set 2 | dikson
# Processing Record 1 of Set 3 | porto novo
# Processing Record 2 of Set 3 | narsaq
# Processing Record 3 of Set 3 | pevek
# Processing Record 4 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 7 of Set 3 | port lincoln
# Processing Record 8 of Set 3 | menomonie
# Processing Record 9 of Set 3 | provideniya
# Processing Record 10 of Set 3 | weligama
# Processing Record 11 of Set 3 | lagoa
# Processing Record 12 of Set 3 | haimen
# Processing Record 13 of Set 3 | bengkulu
# Processing Record 14 of Set 3 | aljezur
# Processing Record 15 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 3 | akyab
# Processing Record 17 of Set 3 | port elizabeth
# Processing Record 18 of Set 3 | sulangan
# Processing Record 19 of Set 3 | arraial do cabo
# Processing Record 20 of Set 3 | ponta delgada
# Processing Record 21 of Set 3 | port blair
# Processing Record 22 of Set 3 | smithers
# Processing Record 23 of Set 3 | kumukh
# Processing Record 24 of Set 3 | saint-philippe
# Processing Record 25 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 3 | sohag
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | cabo san lucas
# Processing Record 29 of Set 3 | ridgecrest
# Processing Record 30 of Set 3 | marion
# Processing Record 31 of Set 3 | san patricio
# Processing Record 32 of Set 3 | noshiro
# Processing Record 33 of Set 3 | namatanai
# Processing Record 34 of Set 3 | beringovskiy
# Processing Record 35 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 3 | chicama
# Processing Record 37 of Set 3 | sao miguel do araguaia
# Processing Record 38 of Set 3 | fairbanks
# Processing Record 39 of Set 3 | luancheng
# Processing Record 40 of Set 3 | tura
# Processing Record 41 of Set 3 | longyearbyen
# Processing Record 42 of Set 3 | new norfolk
# Processing Record 43 of Set 3 | tabory
# Processing Record 44 of Set 3 | umuarama
# Processing Record 45 of Set 3 | faya
# Processing Record 46 of Set 3 | anqing
# Processing Record 47 of Set 3 | srednekolymsk
# Processing Record 48 of Set 3 | tanggu
# Processing Record 49 of Set 3 | coihaique
# Processing Record 50 of Set 3 | northam
# Processing Record 1 of Set 4 | hobart
# Processing Record 2 of Set 4 | sumbe
# Processing Record 3 of Set 4 | bathsheba
# Processing Record 4 of Set 4 | calimanesti
# Processing Record 5 of Set 4 | saint-pierre
# Processing Record 6 of Set 4 | kungurtug
# Processing Record 7 of Set 4 | dubasari
# Processing Record 8 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 4 | makakilo city
# Processing Record 10 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 4 | sao felix do xingu
# Processing Record 12 of Set 4 | madang
# Processing Record 13 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 14 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 4 | kloulklubed
# Processing Record 16 of Set 4 | kaitong
# Processing Record 17 of Set 4 | katsuura
# Processing Record 18 of Set 4 | ostrovnoy
# Processing Record 19 of Set 4 | ramsey
# Processing Record 20 of Set 4 | plettenberg bay
# Processing Record 21 of Set 4 | guntakal
# Processing Record 22 of Set 4 | tiksi
# Processing Record 23 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 4 | isangel
# Processing Record 25 of Set 4 | hilo
# Processing Record 26 of Set 4 | jalu
# Processing Record 27 of Set 4 | esperance
# Processing Record 28 of Set 4 | flin flon
# Processing Record 29 of Set 4 | nishihara
# Processing Record 30 of Set 4 | christchurch
# Processing Record 31 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 4 | havoysund
# Processing Record 33 of Set 4 | souillac
# Processing Record 34 of Set 4 | nome
# Processing Record 35 of Set 4 | deniliquin
# Processing Record 36 of Set 4 | palmares do sul
# Processing Record 37 of Set 4 | kysyl-syr
# Processing Record 38 of Set 4 | tuatapere
# Processing Record 39 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 4 | honningsvag
# Processing Record 41 of Set 4 | gambela
# Processing Record 42 of Set 4 | tasiilaq
# Processing Record 43 of Set 4 | westport
# Processing Record 44 of Set 4 | port alfred
# Processing Record 45 of Set 4 | koyilandi
# City not found. Skipping...
# Processing Record 46 of Set 4 | luganville
# Processing Record 47 of Set 4 | torbay
# Processing Record 48 of Set 4 | marystown
# Processing Record 49 of Set 4 | carnarvon
# Processing Record 50 of Set 4 | camacha
# Processing Record 1 of Set 5 | victoria
# Processing Record 2 of Set 5 | malabo
# Processing Record 3 of Set 5 | nizhniy kuranakh
# Processing Record 4 of Set 5 | bam
# Processing Record 5 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 5 | darnah
# Processing Record 7 of Set 5 | ornes
# Processing Record 8 of Set 5 | ponta do sol
# Processing Record 9 of Set 5 | upernavik
# Processing Record 10 of Set 5 | tomislavgrad
# Processing Record 11 of Set 5 | taoudenni
# Processing Record 12 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 5 | salamanca
# Processing Record 14 of Set 5 | kaeo
# Processing Record 15 of Set 5 | labuhan
# Processing Record 16 of Set 5 | semey
# Processing Record 17 of Set 5 | nizhniy odes
# Processing Record 18 of Set 5 | bethel
# Processing Record 19 of Set 5 | avarua
# Processing Record 20 of Set 5 | constitucion
# Processing Record 21 of Set 5 | kargalinskaya
# Processing Record 22 of Set 5 | higuey
# City not found. Skipping...
# Processing Record 23 of Set 5 | portland
# Processing Record 24 of Set 5 | kondinskoye
# Processing Record 25 of Set 5 | baruun-urt
# Processing Record 26 of Set 5 | orje
# Processing Record 27 of Set 5 | vostok
# Processing Record 28 of Set 5 | coos bay
# Processing Record 29 of Set 5 | hasaki
# Processing Record 30 of Set 5 | jose bonifacio
# Processing Record 31 of Set 5 | vila velha
# Processing Record 32 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 5 | targsorul-vechi
# City not found. Skipping...
# Processing Record 34 of Set 5 | taksimo
# Processing Record 35 of Set 5 | hunchun
# Processing Record 36 of Set 5 | shostka
# Processing Record 37 of Set 5 | saskylakh
# Processing Record 38 of Set 5 | chuy
# Processing Record 39 of Set 5 | gao
# Processing Record 40 of Set 5 | banda aceh
# Processing Record 41 of Set 5 | beidao
# Processing Record 42 of Set 5 | vila
# Processing Record 43 of Set 5 | castro
# Processing Record 44 of Set 5 | broken hill
# Processing Record 45 of Set 5 | kudahuvadhoo
# Processing Record 46 of Set 5 | kahului
# Processing Record 47 of Set 5 | touros
# Processing Record 48 of Set 5 | kutum
# Processing Record 49 of Set 5 | khorixas
# Processing Record 50 of Set 5 | eugene
# Processing Record 1 of Set 6 | naryan-mar
# Processing Record 2 of Set 6 | vytegra
# Processing Record 3 of Set 6 | pozo colorado
# Processing Record 4 of Set 6 | pangody
# Processing Record 5 of Set 6 | mayo
# Processing Record 6 of Set 6 | upington
# Processing Record 7 of Set 6 | blagoyevo
# Processing Record 8 of Set 6 | tondano
# Processing Record 9 of Set 6 | phuthaditjhaba
# Processing Record 10 of Set 6 | nyurba
# Processing Record 11 of Set 6 | zhezkazgan
# Processing Record 12 of Set 6 | caravelas
# Processing Record 13 of Set 6 | clyde river
# Processing Record 14 of Set 6 | dahegam
# Processing Record 15 of Set 6 | pakisaji
# Processing Record 16 of Set 6 | chanute
# Processing Record 17 of Set 6 | lorengau
# Processing Record 18 of Set 6 | aklavik
# Processing Record 19 of Set 6 | cherskiy
# Processing Record 20 of Set 6 | san andres
# Processing Record 21 of Set 6 | friedrichsdorf
# Processing Record 22 of Set 6 | george
# Processing Record 23 of Set 6 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 24 of Set 6 | tautira
# Processing Record 25 of Set 6 | xinyu
# Processing Record 26 of Set 6 | lata
# Processing Record 27 of Set 6 | faanui
# Processing Record 28 of Set 6 | phuket
# Processing Record 29 of Set 6 | araceli
# Processing Record 30 of Set 6 | edendale
# Processing Record 31 of Set 6 | katherine
# Processing Record 32 of Set 6 | calabar
# Processing Record 33 of Set 6 | diamantino
# Processing Record 34 of Set 6 | koubia
# Processing Record 35 of Set 6 | ereymentau
# Processing Record 36 of Set 6 | baykit
# Processing Record 37 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 38 of Set 6 | dajal
# Processing Record 39 of Set 6 | alibag
# Processing Record 40 of Set 6 | margherita
# Processing Record 41 of Set 6 | darhan
# Processing Record 42 of Set 6 | sechura
# Processing Record 43 of Set 6 | santa cruz
# Processing Record 44 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 6 | naftah
# City not found. Skipping...
# Processing Record 46 of Set 6 | galveston
# Processing Record 47 of Set 6 | takapau
# Processing Record 48 of Set 6 | leh
# Processing Record 49 of Set 6 | road town
# Processing Record 50 of Set 6 | batemans bay
# Processing Record 1 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 7 | shahreza
# Processing Record 3 of Set 7 | gat
# Processing Record 4 of Set 7 | hami
# Processing Record 5 of Set 7 | los llanos de aridane
# Processing Record 6 of Set 7 | kruisfontein
# Processing Record 7 of Set 7 | malakal
# Processing Record 8 of Set 7 | karratha
# Processing Record 9 of Set 7 | geraldton
# Processing Record 10 of Set 7 | neyshabur
# Processing Record 11 of Set 7 | airai
# Processing Record 12 of Set 7 | sakaiminato
# Processing Record 13 of Set 7 | tual
# Processing Record 14 of Set 7 | valuyki
# Processing Record 15 of Set 7 | novyy urgal
# Processing Record 16 of Set 7 | cocorit
# Processing Record 17 of Set 7 | sivaki
# Processing Record 18 of Set 7 | mehamn
# Processing Record 19 of Set 7 | porto velho
# Processing Record 20 of Set 7 | invermere
# Processing Record 21 of Set 7 | angoche
# Processing Record 22 of Set 7 | tukrah
# Processing Record 23 of Set 7 | sioux lookout
# Processing Record 24 of Set 7 | sucre
# Processing Record 25 of Set 7 | turukhansk
# Processing Record 26 of Set 7 | kavieng
# Processing Record 27 of Set 7 | karaton
# Processing Record 28 of Set 7 | kalmunai
# Processing Record 29 of Set 7 | kirkwall
# Processing Record 30 of Set 7 | adrar
# Processing Record 31 of Set 7 | sumter
# Processing Record 32 of Set 7 | quixada
# Processing Record 33 of Set 7 | te anau
# Processing Record 34 of Set 7 | mahebourg
# Processing Record 35 of Set 7 | laureles
# Processing Record 36 of Set 7 | paamiut
# Processing Record 37 of Set 7 | emba
# Processing Record 38 of Set 7 | iqaluit
# Processing Record 39 of Set 7 | ust-maya
# Processing Record 40 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 7 | georgetown
# Processing Record 42 of Set 7 | alice springs
# Processing Record 43 of Set 7 | villa carlos paz
# Processing Record 44 of Set 7 | port hardy
# Processing Record 45 of Set 7 | marrakesh
# Processing Record 46 of Set 7 | baripada
# Processing Record 47 of Set 7 | husavik
# Processing Record 48 of Set 7 | marawi
# Processing Record 49 of Set 7 | oshikango
# Processing Record 50 of Set 7 | college
# Processing Record 1 of Set 8 | lubyany
# Processing Record 2 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 8 | shitanjing
# Processing Record 4 of Set 8 | acarau
# Processing Record 5 of Set 8 | yumen
# Processing Record 6 of Set 8 | sept-iles
# Processing Record 7 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 8 of Set 8 | namibe
# Processing Record 9 of Set 8 | cedar city
# Processing Record 10 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 8 | manokwari
# Processing Record 12 of Set 8 | itarema
# Processing Record 13 of Set 8 | payo
# Processing Record 14 of Set 8 | talnakh
# Processing Record 15 of Set 8 | komsomolskiy
# Processing Record 16 of Set 8 | matagami
# Processing Record 17 of Set 8 | iberia
# Processing Record 18 of Set 8 | vao
# Processing Record 19 of Set 8 | boende
# Processing Record 20 of Set 8 | bainbridge
# Processing Record 21 of Set 8 | alvaraes
# Processing Record 22 of Set 8 | lazaro cardenas
# Processing Record 23 of Set 8 | litovko
# Processing Record 24 of Set 8 | sur
# Processing Record 25 of Set 8 | palana
# Processing Record 26 of Set 8 | rongcheng
# Processing Record 27 of Set 8 | bosaso
# Processing Record 28 of Set 8 | manaus
# Processing Record 29 of Set 8 | bo rai
# Processing Record 30 of Set 8 | champerico
# Processing Record 31 of Set 8 | rio grande
# Processing Record 32 of Set 8 | rio gallegos
# Processing Record 33 of Set 8 | latung
# Processing Record 34 of Set 8 | lompoc
# Processing Record 35 of Set 8 | susaki
# Processing Record 36 of Set 8 | cayenne
# Processing Record 37 of Set 8 | ixtapa
# Processing Record 38 of Set 8 | matamoros
# Processing Record 39 of Set 8 | derzhavinsk
# Processing Record 40 of Set 8 | codrington
# Processing Record 41 of Set 8 | san policarpo
# Processing Record 42 of Set 8 | yakovlevka
# Processing Record 43 of Set 8 | abha
# Processing Record 44 of Set 8 | linxia
# Processing Record 45 of Set 8 | dingle
# Processing Record 46 of Set 8 | leningradskiy
# Processing Record 47 of Set 8 | varkkallai
# Processing Record 48 of Set 8 | paramirim
# Processing Record 49 of Set 8 | chenzhou
# Processing Record 50 of Set 8 | alofi
# Processing Record 1 of Set 9 | dauphin
# Processing Record 2 of Set 9 | nanortalik
# Processing Record 3 of Set 9 | progreso
# Processing Record 4 of Set 9 | scarborough
# Processing Record 5 of Set 9 | tymovskoye
# Processing Record 6 of Set 9 | wanaka
# Processing Record 7 of Set 9 | la asuncion
# Processing Record 8 of Set 9 | papillion
# Processing Record 9 of Set 9 | belmonte
# Processing Record 10 of Set 9 | gresham
# Processing Record 11 of Set 9 | samarai
# Processing Record 12 of Set 9 | harlingen
# Processing Record 13 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 14 of Set 9 | kirksville
# Processing Record 15 of Set 9 | kathmandu
# Processing Record 16 of Set 9 | nizhniy tsasuchey
# Processing Record 17 of Set 9 | manakara
# Processing Record 18 of Set 9 | panaba
# Processing Record 19 of Set 9 | hovd
# Processing Record 20 of Set 9 | korla
# Processing Record 21 of Set 9 | zhob
# Processing Record 22 of Set 9 | kiama
# Processing Record 23 of Set 9 | kosino
# Processing Record 24 of Set 9 | qaqortoq
# Processing Record 25 of Set 9 | padang
# Processing Record 26 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 9 | nhulunbuy
# Processing Record 28 of Set 9 | palmer
# Processing Record 29 of Set 9 | anse-bertrand
# Processing Record 30 of Set 9 | suluq
# Processing Record 31 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 9 | berdigestyakh
# Processing Record 33 of Set 9 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 9 | siilinjarvi
# Processing Record 35 of Set 9 | bandarbeyla
# Processing Record 36 of Set 9 | yzeure
# Processing Record 37 of Set 9 | majene
# Processing Record 38 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 9 | horsham
# Processing Record 40 of Set 9 | guerrero negro
# Processing Record 41 of Set 9 | pflugerville
# Processing Record 42 of Set 9 | oistins
# Processing Record 43 of Set 9 | omsukchan
# Processing Record 44 of Set 9 | urumqi
# Processing Record 45 of Set 9 | okhotsk
# Processing Record 46 of Set 9 | sao borja
# Processing Record 47 of Set 9 | yakeshi
# Processing Record 48 of Set 9 | rawson
# Processing Record 49 of Set 9 | bilibino
# Processing Record 50 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 1 of Set 10 | hobyo
# Processing Record 2 of Set 10 | sola
# Processing Record 3 of Set 10 | egvekinot
# Processing Record 4 of Set 10 | brae
# Processing Record 5 of Set 10 | negele
# City not found. Skipping...
# Processing Record 6 of Set 10 | camana
# Processing Record 7 of Set 10 | antofagasta
# Processing Record 8 of Set 10 | terrace bay
# Processing Record 9 of Set 10 | farafangana
# Processing Record 10 of Set 10 | ahuimanu
# Processing Record 11 of Set 10 | curuca
# Processing Record 12 of Set 10 | nanae
# Processing Record 13 of Set 10 | sibirtsevo
# City not found. Skipping...
# Processing Record 14 of Set 10 | bemidji
# Processing Record 15 of Set 10 | kawalu
# Processing Record 16 of Set 10 | paita
# Processing Record 17 of Set 10 | santa fe
# Processing Record 18 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 19 of Set 10 | altay
# Processing Record 20 of Set 10 | buraydah
# Processing Record 21 of Set 10 | ji-parana
# City not found. Skipping...
# Processing Record 22 of Set 10 | kapoeta
# Processing Record 23 of Set 10 | rucheng
# Processing Record 24 of Set 10 | banmo
# City not found. Skipping...
# Processing Record 25 of Set 10 | sawakin
# Processing Record 26 of Set 10 | kazerun
# Processing Record 27 of Set 10 | tateyama
# Processing Record 28 of Set 10 | smirnykh
# Processing Record 29 of Set 10 | kieta
# Processing Record 30 of Set 10 | norwich
# Processing Record 31 of Set 10 | luderitz
# Processing Record 32 of Set 10 | storsteinnes
# Processing Record 33 of Set 10 | kollam
# Processing Record 34 of Set 10 | terrace
# Processing Record 35 of Set 10 | anadyr
# Processing Record 36 of Set 10 | ca mau
# Processing Record 37 of Set 10 | yulara
# Processing Record 38 of Set 10 | sembe
# Processing Record 39 of Set 10 | luwuk
# Processing Record 40 of Set 10 | margate
# Processing Record 41 of Set 10 | buala
# Processing Record 42 of Set 10 | sao filipe
# Processing Record 43 of Set 10 | gore
# Processing Record 44 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 10 | salalah
# Processing Record 46 of Set 10 | mecca
# Processing Record 47 of Set 10 | kaduna
# Processing Record 48 of Set 10 | karatuzskoye
# Processing Record 49 of Set 10 | junction city
# Processing Record 50 of Set 10 | coquimbo
# Processing Record 1 of Set 11 | kijang
# Processing Record 2 of Set 11 | gilbues
# Processing Record 3 of Set 11 | iralaya
# Processing Record 4 of Set 11 | abu samrah
# Processing Record 5 of Set 11 | san juan
# Processing Record 6 of Set 11 | bingol
# Processing Record 7 of Set 11 | poum
# Processing Record 8 of Set 11 | vanimo
# Processing Record 9 of Set 11 | aden
# Processing Record 10 of Set 11 | north bend
# Processing Record 11 of Set 11 | franklin
# Processing Record 12 of Set 11 | piacabucu
# Processing Record 13 of Set 11 | wewak
# Processing Record 14 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 11 | sandwick
# Processing Record 16 of Set 11 | naze
# Processing Record 17 of Set 11 | cockburn town
# Processing Record 18 of Set 11 | ulaangom
# Processing Record 19 of Set 11 | tanout
# Processing Record 20 of Set 11 | pemangkat
# Processing Record 21 of Set 11 | kotovo
# Processing Record 22 of Set 11 | sisimiut
# Processing Record 23 of Set 11 | hervey bay
# Processing Record 24 of Set 11 | tocopilla
# Processing Record 25 of Set 11 | bud
# Processing Record 26 of Set 11 | senneterre
# Processing Record 27 of Set 11 | chikitigarh
# Processing Record 28 of Set 11 | wichita falls
# Processing Record 29 of Set 11 | lavrentiya
# Processing Record 30 of Set 11 | tucumcari
# Processing Record 31 of Set 11 | praia da vitoria
# Processing Record 32 of Set 11 | coahuayana
# Processing Record 33 of Set 11 | kendari
# Processing Record 34 of Set 11 | vagur
# Processing Record 35 of Set 11 | candawaga
# City not found. Skipping...
# Processing Record 36 of Set 11 | riyadh
# Processing Record 37 of Set 11 | andenes
# Processing Record 38 of Set 11 | ouadda
# Processing Record 39 of Set 11 | fare
# Processing Record 40 of Set 11 | itacoatiara
# Processing Record 41 of Set 11 | domoni
# Processing Record 42 of Set 11 | waddan
# Processing Record 43 of Set 11 | olinda
# Processing Record 44 of Set 11 | baculin
# Processing Record 45 of Set 11 | kayalpattinam
# Processing Record 46 of Set 11 | moree
# Processing Record 47 of Set 11 | ugoofaaru
# Processing Record 48 of Set 11 | livani
# Processing Record 49 of Set 11 | apac
# Processing Record 50 of Set 11 | mumbwa
# Processing Record 1 of Set 12 | panzhihua
# Processing Record 2 of Set 12 | sorland
# Processing Record 3 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 12 | norman wells
# Processing Record 5 of Set 12 | barinitas
# Processing Record 6 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 7 of Set 12 | soto la marina
# Processing Record 8 of Set 12 | omboue
# Processing Record 9 of Set 12 | dhidhdhoo
# Processing Record 10 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 11 of Set 12 | rovaniemi
# Processing Record 12 of Set 12 | general roca
# Processing Record 13 of Set 12 | gardelegen
# Processing Record 14 of Set 12 | alta gracia
# Processing Record 15 of Set 12 | shalya
# Processing Record 16 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 17 of Set 12 | usinsk
# Processing Record 18 of Set 12 | brownsville
# Processing Record 19 of Set 12 | mount isa
# Processing Record 20 of Set 12 | lichinga
# Processing Record 21 of Set 12 | kampene
# Processing Record 22 of Set 12 | lengshuitan
# Processing Record 23 of Set 12 | saraland
# Processing Record 24 of Set 12 | yinchuan
# Processing Record 25 of Set 12 | manacapuru
# Processing Record 26 of Set 12 | abalak
# Processing Record 27 of Set 12 | tornio
# Processing Record 28 of Set 12 | soyo
# Processing Record 29 of Set 12 | kiruna
# Processing Record 30 of Set 12 | saint george
# Processing Record 31 of Set 12 | embonas
# Processing Record 32 of Set 12 | leirvik
# Processing Record 33 of Set 12 | santa marta
# Processing Record 34 of Set 12 | honiara
# Processing Record 35 of Set 12 | astorga
# Processing Record 36 of Set 12 | seoul
# Processing Record 37 of Set 12 | vrangel
# Processing Record 38 of Set 12 | golkoy
# Processing Record 39 of Set 12 | ouargaye
# Processing Record 40 of Set 12 | yar-sale
# Processing Record 41 of Set 12 | alpena
# Processing Record 42 of Set 12 | esik
# Processing Record 43 of Set 12 | tabas
# Processing Record 44 of Set 12 | tlahualilo
# City not found. Skipping...
# Processing Record 45 of Set 12 | druskininkai
# Processing Record 46 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 12 | gravdal
# Processing Record 48 of Set 12 | steinbach
# Processing Record 49 of Set 12 | jumla
# Processing Record 50 of Set 12 | sinnamary
# Processing Record 1 of Set 13 | bima
# Processing Record 2 of Set 13 | fort nelson
# Processing Record 3 of Set 13 | saint-francois
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea -23.1203 -134.9692     78.44        67           6
# 1          Garowe   8.4054   48.4845     71.04        52          67
# 2        Saldanha -33.0117   17.9442     69.80        73          30
# 3  Saint-Augustin  51.2260  -58.6502     34.47        97         100
# 4       Cape Town -33.9258   18.4232     71.01        82          90
# 5          Kodiak  57.7900 -152.4072     39.20        60           1
# 6        Klaksvik  62.2266   -6.5890     28.40        93          97
# 7         Ardatov  55.2421   43.0970     33.57        97         100
# 8       Busselton -33.6500  115.3333     60.01        90          19
# 9     Trincomalee   8.5711   81.2335     78.06        75           1
#
#    Wind Speed Country                 Date
# 0       11.10      PF  2021-01-23 17:45:19
# 1       17.25      SO  2021-01-23 17:45:19
# 2       16.11      ZA  2021-01-23 17:45:20
# 3        9.64      CA  2021-01-23 17:45:20
# 4       14.97      ZA  2021-01-23 17:42:50
# 5       10.36      US  2021-01-23 17:45:20
# 6       14.41      FO  2021-01-23 17:45:20
# 7       13.91      RU  2021-01-23 17:45:20
# 8        2.26      AU  2021-01-23 17:45:21
# 9       11.14      LK  2021-01-23 17:45:21

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0         Rikitea      PF  2021-01-23 17:45:19 -23.1203 -134.9692     78.44
# 1          Garowe      SO  2021-01-23 17:45:19   8.4054   48.4845     71.04
# 2        Saldanha      ZA  2021-01-23 17:45:20 -33.0117   17.9442     69.80
# 3  Saint-Augustin      CA  2021-01-23 17:45:20  51.2260  -58.6502     34.47
# 4       Cape Town      ZA  2021-01-23 17:42:50 -33.9258   18.4232     71.01
# 5          Kodiak      US  2021-01-23 17:45:20  57.7900 -152.4072     39.20
# 6        Klaksvik      FO  2021-01-23 17:45:20  62.2266   -6.5890     28.40
# 7         Ardatov      RU  2021-01-23 17:45:20  55.2421   43.0970     33.57
# 8       Busselton      AU  2021-01-23 17:45:21 -33.6500  115.3333     60.01
# 9     Trincomalee      LK  2021-01-23 17:45:21   8.5711   81.2335     78.06
#
#    Humidity  Cloudiness  Wind Speed
# 0        67           6       11.10
# 1        52          67       17.25
# 2        73          30       16.11
# 3        97         100        9.64
# 4        82          90       14.97
# 5        60           1       10.36
# 6        93          97       14.41
# 7        97         100       13.91
# 8        90          19        2.26
# 9        75           1       11.14

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

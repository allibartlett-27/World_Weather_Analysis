# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 771

# %%
#Import the requests library. 
import requests

#Import the API Key. 
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | huarmey
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | fairbanks
# Processing Record 7 of Set 1 | margate
# Processing Record 8 of Set 1 | nova olinda do norte
# Processing Record 9 of Set 1 | kang
# Processing Record 10 of Set 1 | caravelas
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | ahipara
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | sokoni
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | eskasem
# City not found. Skipping...
# Processing Record 20 of Set 1 | nhulunbuy
# Processing Record 21 of Set 1 | murray bridge
# Processing Record 22 of Set 1 | hamilton
# Processing Record 23 of Set 1 | arona
# Processing Record 24 of Set 1 | strezhevoy
# Processing Record 25 of Set 1 | aklavik
# Processing Record 26 of Set 1 | lavrentiya
# Processing Record 27 of Set 1 | vila velha
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | yuci
# Processing Record 30 of Set 1 | marsaxlokk
# Processing Record 31 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 1 | guerrero negro
# Processing Record 33 of Set 1 | saint-pierre
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | karlstad
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | sambava
# Processing Record 39 of Set 1 | tura
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | meulaboh
# Processing Record 42 of Set 1 | nador
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | porto novo
# Processing Record 45 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 1 | hami
# Processing Record 47 of Set 1 | sao joao da barra
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | pisco
# Processing Record 50 of Set 1 | abu dhabi
# Processing Record 1 of Set 2 | kaitangata
# Processing Record 2 of Set 2 | holysov
# Processing Record 3 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | saint george
# Processing Record 6 of Set 2 | provideniya
# Processing Record 7 of Set 2 | torbay
# Processing Record 8 of Set 2 | afmadu
# City not found. Skipping...
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | centralia
# Processing Record 11 of Set 2 | alakurtti
# Processing Record 12 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | charcas
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 17 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 2 | coquimbo
# Processing Record 19 of Set 2 | truth or consequences
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | khatanga
# Processing Record 22 of Set 2 | arman
# Processing Record 23 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 2 | tukrah
# Processing Record 25 of Set 2 | praia da vitoria
# Processing Record 26 of Set 2 | egvekinot
# Processing Record 27 of Set 2 | luganville
# Processing Record 28 of Set 2 | roma
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | grand gaube
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | fortuna
# Processing Record 34 of Set 2 | lagoa
# Processing Record 35 of Set 2 | berlevag
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | vestmannaeyjar
# Processing Record 38 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 39 of Set 2 | kathmandu
# Processing Record 40 of Set 2 | turayf
# Processing Record 41 of Set 2 | beyneu
# Processing Record 42 of Set 2 | bethanien
# Processing Record 43 of Set 2 | along
# Processing Record 44 of Set 2 | portland
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | kruisfontein
# Processing Record 47 of Set 2 | moose factory
# Processing Record 48 of Set 2 | karratha
# Processing Record 49 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | yellowknife
# Processing Record 2 of Set 3 | jimeta
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | cidreira
# Processing Record 7 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 3 | mareeba
# Processing Record 9 of Set 3 | buin
# Processing Record 10 of Set 3 | lima
# Processing Record 11 of Set 3 | teluknaga
# Processing Record 12 of Set 3 | isangel
# Processing Record 13 of Set 3 | marang
# Processing Record 14 of Set 3 | nouadhibou
# Processing Record 15 of Set 3 | vallenar
# Processing Record 16 of Set 3 | nanortalik
# Processing Record 17 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 3 | banjarmasin
# Processing Record 19 of Set 3 | zolotinka
# City not found. Skipping...
# Processing Record 20 of Set 3 | walvis bay
# Processing Record 21 of Set 3 | katsuura
# Processing Record 22 of Set 3 | barcelona
# Processing Record 23 of Set 3 | upernavik
# Processing Record 24 of Set 3 | hasaki
# Processing Record 25 of Set 3 | imbituba
# Processing Record 26 of Set 3 | tiksi
# Processing Record 27 of Set 3 | erenhot
# Processing Record 28 of Set 3 | tuktoyaktuk
# Processing Record 29 of Set 3 | beira
# Processing Record 30 of Set 3 | bontang
# Processing Record 31 of Set 3 | carnarvon
# Processing Record 32 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 3 | east london
# Processing Record 34 of Set 3 | scottsbluff
# Processing Record 35 of Set 3 | teguldet
# Processing Record 36 of Set 3 | goderich
# Processing Record 37 of Set 3 | healesville
# Processing Record 38 of Set 3 | norman wells
# Processing Record 39 of Set 3 | bathsheba
# Processing Record 40 of Set 3 | mizan teferi
# Processing Record 41 of Set 3 | bonthe
# Processing Record 42 of Set 3 | puerto leguizamo
# Processing Record 43 of Set 3 | kodiak
# Processing Record 44 of Set 3 | kavieng
# Processing Record 45 of Set 3 | marrakesh
# Processing Record 46 of Set 3 | berbera
# Processing Record 47 of Set 3 | dicabisagan
# Processing Record 48 of Set 3 | puerto ayora
# Processing Record 49 of Set 3 | chuy
# Processing Record 50 of Set 3 | ferkessedougou
# Processing Record 1 of Set 4 | port macquarie
# Processing Record 2 of Set 4 | la palma
# Processing Record 3 of Set 4 | mahebourg
# Processing Record 4 of Set 4 | jalesar
# Processing Record 5 of Set 4 | smithers
# Processing Record 6 of Set 4 | desoto
# Processing Record 7 of Set 4 | port-gentil
# Processing Record 8 of Set 4 | bogande
# Processing Record 9 of Set 4 | taoudenni
# Processing Record 10 of Set 4 | cody
# Processing Record 11 of Set 4 | hermanus
# Processing Record 12 of Set 4 | besenyszog
# Processing Record 13 of Set 4 | mayo
# Processing Record 14 of Set 4 | mapiripan
# Processing Record 15 of Set 4 | yuzhno-sukhokumsk
# Processing Record 16 of Set 4 | mildura
# Processing Record 17 of Set 4 | pevek
# Processing Record 18 of Set 4 | dikson
# Processing Record 19 of Set 4 | prince rupert
# Processing Record 20 of Set 4 | ulladulla
# Processing Record 21 of Set 4 | hualmay
# Processing Record 22 of Set 4 | faanui
# Processing Record 23 of Set 4 | sistranda
# Processing Record 24 of Set 4 | asyut
# Processing Record 25 of Set 4 | severo-kurilsk
# Processing Record 26 of Set 4 | saldanha
# Processing Record 27 of Set 4 | hervey bay
# Processing Record 28 of Set 4 | brae
# Processing Record 29 of Set 4 | bambous virieux
# Processing Record 30 of Set 4 | yokadouma
# Processing Record 31 of Set 4 | sitka
# Processing Record 32 of Set 4 | butaritari
# Processing Record 33 of Set 4 | ahuimanu
# Processing Record 34 of Set 4 | clarence town
# Processing Record 35 of Set 4 | kallithea
# Processing Record 36 of Set 4 | great yarmouth
# Processing Record 37 of Set 4 | novooleksiyivka
# Processing Record 38 of Set 4 | takoradi
# Processing Record 39 of Set 4 | sibu
# Processing Record 40 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 4 | bethel
# Processing Record 42 of Set 4 | lebu
# Processing Record 43 of Set 4 | grand-santi
# Processing Record 44 of Set 4 | grindavik
# Processing Record 45 of Set 4 | broken hill
# Processing Record 46 of Set 4 | bilibino
# Processing Record 47 of Set 4 | bereda
# Processing Record 48 of Set 4 | ciudad bolivar
# Processing Record 49 of Set 4 | tiznit
# Processing Record 50 of Set 4 | atar
# Processing Record 1 of Set 5 | pangody
# Processing Record 2 of Set 5 | comodoro rivadavia
# Processing Record 3 of Set 5 | dickinson
# Processing Record 4 of Set 5 | trapani
# Processing Record 5 of Set 5 | tomatlan
# Processing Record 6 of Set 5 | vostok
# Processing Record 7 of Set 5 | san patricio
# Processing Record 8 of Set 5 | visnes
# Processing Record 9 of Set 5 | yar-sale
# Processing Record 10 of Set 5 | la primavera
# Processing Record 11 of Set 5 | baft
# Processing Record 12 of Set 5 | kingaroy
# Processing Record 13 of Set 5 | guaruja
# Processing Record 14 of Set 5 | cabedelo
# Processing Record 15 of Set 5 | koumac
# Processing Record 16 of Set 5 | astoria
# Processing Record 17 of Set 5 | pouebo
# Processing Record 18 of Set 5 | tabou
# Processing Record 19 of Set 5 | saint-philippe
# Processing Record 20 of Set 5 | yablochnyy
# Processing Record 21 of Set 5 | krasnaya gora
# Processing Record 22 of Set 5 | srednekolymsk
# Processing Record 23 of Set 5 | chapais
# Processing Record 24 of Set 5 | maceio
# Processing Record 25 of Set 5 | pocone
# Processing Record 26 of Set 5 | dandong
# Processing Record 27 of Set 5 | djibo
# Processing Record 28 of Set 5 | broome
# Processing Record 29 of Set 5 | sayyan
# Processing Record 30 of Set 5 | constitucion
# Processing Record 31 of Set 5 | geraldton
# Processing Record 32 of Set 5 | baherden
# Processing Record 33 of Set 5 | namatanai
# Processing Record 34 of Set 5 | yerbogachen
# Processing Record 35 of Set 5 | phek
# Processing Record 36 of Set 5 | mabaruma
# Processing Record 37 of Set 5 | victoria
# Processing Record 38 of Set 5 | talnakh
# Processing Record 39 of Set 5 | sarankhola
# Processing Record 40 of Set 5 | nemuro
# Processing Record 41 of Set 5 | kahului
# Processing Record 42 of Set 5 | salalah
# Processing Record 43 of Set 5 | yataity del norte
# Processing Record 44 of Set 5 | butajira
# Processing Record 45 of Set 5 | tsienyane
# City not found. Skipping...
# Processing Record 46 of Set 5 | sosnovo-ozerskoye
# Processing Record 47 of Set 5 | spirit river
# Processing Record 48 of Set 5 | ambilobe
# Processing Record 49 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 50 of Set 5 | saint-michel-des-saints
# Processing Record 1 of Set 6 | the valley
# Processing Record 2 of Set 6 | balkanabat
# Processing Record 3 of Set 6 | wattegama
# Processing Record 4 of Set 6 | bastrop
# Processing Record 5 of Set 6 | muros
# Processing Record 6 of Set 6 | shetpe
# Processing Record 7 of Set 6 | abu samrah
# Processing Record 8 of Set 6 | nizhniy kuranakh
# Processing Record 9 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 6 | ritchie
# Processing Record 11 of Set 6 | itarema
# Processing Record 12 of Set 6 | naze
# Processing Record 13 of Set 6 | ballina
# Processing Record 14 of Set 6 | ahome
# Processing Record 15 of Set 6 | port shepstone
# Processing Record 16 of Set 6 | christchurch
# Processing Record 17 of Set 6 | souillac
# Processing Record 18 of Set 6 | ganganagar
# Processing Record 19 of Set 6 | borovoy
# Processing Record 20 of Set 6 | igarka
# Processing Record 21 of Set 6 | newton
# Processing Record 22 of Set 6 | corumba
# Processing Record 23 of Set 6 | solsvik
# City not found. Skipping...
# Processing Record 24 of Set 6 | ancud
# Processing Record 25 of Set 6 | goundam
# Processing Record 26 of Set 6 | pingzhuang
# Processing Record 27 of Set 6 | muroto
# Processing Record 28 of Set 6 | mlandizi
# Processing Record 29 of Set 6 | bengkulu
# Processing Record 30 of Set 6 | desnogorsk
# Processing Record 31 of Set 6 | chimbote
# Processing Record 32 of Set 6 | auki
# Processing Record 33 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 6 | miri
# Processing Record 35 of Set 6 | marienburg
# Processing Record 36 of Set 6 | jalu
# Processing Record 37 of Set 6 | mar del plata
# Processing Record 38 of Set 6 | morehead
# Processing Record 39 of Set 6 | kamenka
# Processing Record 40 of Set 6 | coxim
# Processing Record 41 of Set 6 | saint-georges
# Processing Record 42 of Set 6 | farafangana
# Processing Record 43 of Set 6 | algeciras
# Processing Record 44 of Set 6 | mookane
# Processing Record 45 of Set 6 | mwinilunga
# Processing Record 46 of Set 6 | yashkul
# Processing Record 47 of Set 6 | coralville
# Processing Record 48 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 49 of Set 6 | kirakira
# Processing Record 50 of Set 6 | hailar
# Processing Record 1 of Set 7 | yeniseysk
# Processing Record 2 of Set 7 | oktyabrskoye
# Processing Record 3 of Set 7 | port blair
# Processing Record 4 of Set 7 | arlit
# Processing Record 5 of Set 7 | baoqing
# Processing Record 6 of Set 7 | buchanan
# Processing Record 7 of Set 7 | clyde river
# Processing Record 8 of Set 7 | volginskiy
# City not found. Skipping...
# Processing Record 9 of Set 7 | san jeronimo
# Processing Record 10 of Set 7 | buta
# Processing Record 11 of Set 7 | kuryk
# Processing Record 12 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 7 | port augusta
# Processing Record 14 of Set 7 | pacific grove
# Processing Record 15 of Set 7 | nikolskoye
# Processing Record 16 of Set 7 | herat
# Processing Record 17 of Set 7 | lompoc
# Processing Record 18 of Set 7 | pemangkat
# Processing Record 19 of Set 7 | bijawar
# Processing Record 20 of Set 7 | camana
# Processing Record 21 of Set 7 | lata
# Processing Record 22 of Set 7 | teahupoo
# Processing Record 23 of Set 7 | gisors
# Processing Record 24 of Set 7 | kupang
# Processing Record 25 of Set 7 | fasa
# Processing Record 26 of Set 7 | pasaje
# Processing Record 27 of Set 7 | masterton
# Processing Record 28 of Set 7 | fengkou
# Processing Record 29 of Set 7 | mauswagon
# City not found. Skipping...
# Processing Record 30 of Set 7 | lajas
# Processing Record 31 of Set 7 | senanga
# Processing Record 32 of Set 7 | lidkoping
# Processing Record 33 of Set 7 | kargasok
# Processing Record 34 of Set 7 | tema
# Processing Record 35 of Set 7 | mount gambier
# Processing Record 36 of Set 7 | yaan
# Processing Record 37 of Set 7 | manzhouli
# Processing Record 38 of Set 7 | manaus
# Processing Record 39 of Set 7 | port lincoln
# Processing Record 40 of Set 7 | nouakchott
# Processing Record 41 of Set 7 | bani
# Processing Record 42 of Set 7 | nantucket
# Processing Record 43 of Set 7 | aguada de pasajeros
# Processing Record 44 of Set 7 | payson
# Processing Record 45 of Set 7 | faya
# Processing Record 46 of Set 7 | fukuma
# Processing Record 47 of Set 7 | wum
# Processing Record 48 of Set 7 | yulara
# Processing Record 49 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 7 | tazovskiy
# Processing Record 1 of Set 8 | collie
# Processing Record 2 of Set 8 | ecoporanga
# Processing Record 3 of Set 8 | sioux lookout
# Processing Record 4 of Set 8 | mitsamiouli
# Processing Record 5 of Set 8 | sadovoye
# Processing Record 6 of Set 8 | alice town
# Processing Record 7 of Set 8 | ostrovnoy
# Processing Record 8 of Set 8 | novomichurinsk
# Processing Record 9 of Set 8 | sao felix do xingu
# Processing Record 10 of Set 8 | kaduqli
# Processing Record 11 of Set 8 | praia
# Processing Record 12 of Set 8 | port hedland
# Processing Record 13 of Set 8 | panalingaan
# Processing Record 14 of Set 8 | batouri
# Processing Record 15 of Set 8 | umm kaddadah
# Processing Record 16 of Set 8 | inuvik
# Processing Record 17 of Set 8 | griffith
# Processing Record 18 of Set 8 | cabo san lucas
# Processing Record 19 of Set 8 | te anau
# Processing Record 20 of Set 8 | el alto
# Processing Record 21 of Set 8 | agadez
# Processing Record 22 of Set 8 | gari
# Processing Record 23 of Set 8 | husavik
# Processing Record 24 of Set 8 | saint-joseph
# Processing Record 25 of Set 8 | dudinka
# Processing Record 26 of Set 8 | mahajanga
# Processing Record 27 of Set 8 | fomboni
# Processing Record 28 of Set 8 | gorgan
# Processing Record 29 of Set 8 | cherskiy
# Processing Record 30 of Set 8 | arrecife
# Processing Record 31 of Set 8 | ponta do sol
# Processing Record 32 of Set 8 | marawi
# Processing Record 33 of Set 8 | taltal
# Processing Record 34 of Set 8 | yining
# Processing Record 35 of Set 8 | inhambane
# Processing Record 36 of Set 8 | rigaud
# Processing Record 37 of Set 8 | pangnirtung
# Processing Record 38 of Set 8 | ust-nera
# Processing Record 39 of Set 8 | pimentel
# Processing Record 40 of Set 8 | pailon
# Processing Record 41 of Set 8 | solnechnyy
# Processing Record 42 of Set 8 | vila franca do campo
# Processing Record 43 of Set 8 | klaksvik
# Processing Record 44 of Set 8 | czestochowa
# Processing Record 45 of Set 8 | rhyl
# Processing Record 46 of Set 8 | vaitape
# Processing Record 47 of Set 8 | seoul
# Processing Record 48 of Set 8 | uusikaupunki
# Processing Record 49 of Set 8 | cap malheureux
# Processing Record 50 of Set 8 | honningsvag
# Processing Record 1 of Set 9 | olinda
# Processing Record 2 of Set 9 | owando
# Processing Record 3 of Set 9 | sur
# Processing Record 4 of Set 9 | scharnstein
# Processing Record 5 of Set 9 | burica
# City not found. Skipping...
# Processing Record 6 of Set 9 | kendari
# Processing Record 7 of Set 9 | shelburne
# Processing Record 8 of Set 9 | jumla
# Processing Record 9 of Set 9 | trelew
# Processing Record 10 of Set 9 | chiang kham
# Processing Record 11 of Set 9 | lokosovo
# Processing Record 12 of Set 9 | mandali
# Processing Record 13 of Set 9 | lobau
# Processing Record 14 of Set 9 | mansa
# Processing Record 15 of Set 9 | mao
# Processing Record 16 of Set 9 | manjakandriana
# Processing Record 17 of Set 9 | axim
# Processing Record 18 of Set 9 | san juan de la maguana
# Processing Record 19 of Set 9 | alugan
# Processing Record 20 of Set 9 | back mountain
# Processing Record 21 of Set 9 | komsomolskiy
# Processing Record 22 of Set 9 | sao filipe
# Processing Record 23 of Set 9 | santa cruz
# Processing Record 24 of Set 9 | eslov
# Processing Record 25 of Set 9 | vertou
# Processing Record 26 of Set 9 | mutum
# Processing Record 27 of Set 9 | jijiga
# Processing Record 28 of Set 9 | laguna
# Processing Record 29 of Set 9 | oranjestad
# Processing Record 30 of Set 9 | mont-de-marsan
# Processing Record 31 of Set 9 | okhotsk
# Processing Record 32 of Set 9 | anshun
# Processing Record 33 of Set 9 | iqaluit
# Processing Record 34 of Set 9 | wonthaggi
# Processing Record 35 of Set 9 | elliot lake
# Processing Record 36 of Set 9 | ilulissat
# Processing Record 37 of Set 9 | chingirlau
# Processing Record 38 of Set 9 | katangli
# Processing Record 39 of Set 9 | serebryansk
# Processing Record 40 of Set 9 | gilbues
# Processing Record 41 of Set 9 | khromtau
# Processing Record 42 of Set 9 | belle fourche
# Processing Record 43 of Set 9 | alofi
# Processing Record 44 of Set 9 | higuey
# City not found. Skipping...
# Processing Record 45 of Set 9 | rochegda
# Processing Record 46 of Set 9 | lappeenranta
# Processing Record 47 of Set 9 | camocim
# Processing Record 48 of Set 9 | teseney
# Processing Record 49 of Set 9 | panzhihua
# Processing Record 50 of Set 9 | kotido
# Processing Record 1 of Set 10 | tuatapere
# Processing Record 2 of Set 10 | am timan
# Processing Record 3 of Set 10 | padang
# Processing Record 4 of Set 10 | ust-kuyga
# Processing Record 5 of Set 10 | touros
# Processing Record 6 of Set 10 | batagay-alyta
# Processing Record 7 of Set 10 | udachnyy
# Processing Record 8 of Set 10 | ketchikan
# Processing Record 9 of Set 10 | guanhaes
# Processing Record 10 of Set 10 | chipinge
# Processing Record 11 of Set 10 | kloulklubed
# Processing Record 12 of Set 10 | necochea
# Processing Record 13 of Set 10 | dedougou
# Processing Record 14 of Set 10 | ajdabiya
# Processing Record 15 of Set 10 | ixtapa
# Processing Record 16 of Set 10 | pachino
# Processing Record 17 of Set 10 | zhuhai
# Processing Record 18 of Set 10 | araouane
# Processing Record 19 of Set 10 | alyangula
# Processing Record 20 of Set 10 | loon op zand
# Processing Record 21 of Set 10 | palmerston
# Processing Record 22 of Set 10 | san cristobal
# Processing Record 23 of Set 10 | codrington
# Processing Record 24 of Set 10 | westport
# Processing Record 25 of Set 10 | les cayes
# Processing Record 26 of Set 10 | goure
# Processing Record 27 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 28 of Set 10 | anadyr
# Processing Record 29 of Set 10 | harper
# Processing Record 30 of Set 10 | saint-louis
# Processing Record 31 of Set 10 | tecoanapa
# Processing Record 32 of Set 10 | quesnel
# Processing Record 33 of Set 10 | linfen
# Processing Record 34 of Set 10 | springfield
# Processing Record 35 of Set 10 | morwell
# Processing Record 36 of Set 10 | tigre
# Processing Record 37 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 38 of Set 10 | puerto madero
# Processing Record 39 of Set 10 | enshi
# Processing Record 40 of Set 10 | ulaanbaatar
# Processing Record 41 of Set 10 | keti bandar
# Processing Record 42 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 43 of Set 10 | janakpur
# Processing Record 44 of Set 10 | asilah
# Processing Record 45 of Set 10 | pokrovsk
# Processing Record 46 of Set 10 | rio gallegos
# Processing Record 47 of Set 10 | shizuishan
# Processing Record 48 of Set 10 | hasilpur
# Processing Record 49 of Set 10 | maragogi
# Processing Record 50 of Set 10 | vao
# Processing Record 1 of Set 11 | opuwo
# Processing Record 2 of Set 11 | tokur
# Processing Record 3 of Set 11 | sergeyevka
# Processing Record 4 of Set 11 | byron bay
# Processing Record 5 of Set 11 | santa rosalia
# Processing Record 6 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 11 | ginda
# Processing Record 8 of Set 11 | hambantota
# Processing Record 9 of Set 11 | wajima
# Processing Record 10 of Set 11 | georgetown
# Processing Record 11 of Set 11 | kavaratti
# Processing Record 12 of Set 11 | marsala
# Processing Record 13 of Set 11 | santa isabel
# Processing Record 14 of Set 11 | alpine
# Processing Record 15 of Set 11 | nagapattinam
# Processing Record 16 of Set 11 | samarai
# Processing Record 17 of Set 11 | sapa
# Processing Record 18 of Set 11 | mosquera
# Processing Record 19 of Set 11 | kijang
# Processing Record 20 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 21 of Set 11 | yalvac
# Processing Record 22 of Set 11 | belaya gora
# Processing Record 23 of Set 11 | rock sound
# Processing Record 24 of Set 11 | port keats
# Processing Record 25 of Set 11 | semirom
# Processing Record 26 of Set 11 | jaciara
# Processing Record 27 of Set 11 | kerrobert
# Processing Record 28 of Set 11 | bonavista
# Processing Record 29 of Set 11 | isiro
# Processing Record 30 of Set 11 | itaituba
# Processing Record 31 of Set 11 | gualaquiza
# Processing Record 32 of Set 11 | shingu
# Processing Record 33 of Set 11 | puerto maldonado
# Processing Record 34 of Set 11 | juneau
# Processing Record 35 of Set 11 | bolshiye uki
# City not found. Skipping...
# Processing Record 36 of Set 11 | finschhafen
# Processing Record 37 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 38 of Set 11 | northam
# Processing Record 39 of Set 11 | samdrup jongkhar
# Processing Record 40 of Set 11 | banda aceh
# Processing Record 41 of Set 11 | mahibadhoo
# Processing Record 42 of Set 11 | sinnamary
# Processing Record 43 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 44 of Set 11 | kushmurun
# Processing Record 45 of Set 11 | masuda
# Processing Record 46 of Set 11 | barranca
# Processing Record 47 of Set 11 | baykit
# Processing Record 48 of Set 11 | samfya
# Processing Record 49 of Set 11 | port-cartier
# Processing Record 50 of Set 11 | ouesso
# Processing Record 1 of Set 12 | ratnagiri
# Processing Record 2 of Set 12 | bela
# Processing Record 3 of Set 12 | lorengau
# Processing Record 4 of Set 12 | ayan
# Processing Record 5 of Set 12 | poum
# Processing Record 6 of Set 12 | raga
# Processing Record 7 of Set 12 | san pedro de uraba
# Processing Record 8 of Set 12 | gimli
# Processing Record 9 of Set 12 | harindanga
# Processing Record 10 of Set 12 | tautira
# Processing Record 11 of Set 12 | dingle
# Processing Record 12 of Set 12 | brive-la-gaillarde
# Processing Record 13 of Set 12 | bara
# Processing Record 14 of Set 12 | tocopilla
# Processing Record 15 of Set 12 | fort nelson
# Processing Record 16 of Set 12 | sao pedro do sul
# Processing Record 17 of Set 12 | longhua
# Processing Record 18 of Set 12 | gravdal
# Processing Record 19 of Set 12 | nsanje
# Processing Record 20 of Set 12 | fredericksburg
# Processing Record 21 of Set 12 | sinnar
# Processing Record 22 of Set 12 | leningradskiy
# Processing Record 23 of Set 12 | hirara
# Processing Record 24 of Set 12 | kochubey
# Processing Record 25 of Set 12 | ordu
# Processing Record 26 of Set 12 | deputatskiy
# Processing Record 27 of Set 12 | burnie
# Processing Record 28 of Set 12 | longyearbyen
# Processing Record 29 of Set 12 | daxian
# City not found. Skipping...
# Processing Record 30 of Set 12 | novobirilyussy
# Processing Record 31 of Set 12 | narsaq
# Processing Record 32 of Set 12 | santa rosa
# Processing Record 33 of Set 12 | guilin
# Processing Record 34 of Set 12 | mana
# Processing Record 35 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 12 | miranda
# Processing Record 37 of Set 12 | port hardy
# Processing Record 38 of Set 12 | teya
# Processing Record 39 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 12 | lhokseumawe
# Processing Record 41 of Set 12 | viransehir
# Processing Record 42 of Set 12 | calama
# Processing Record 43 of Set 12 | buala
# Processing Record 44 of Set 12 | polunochnoye
# Processing Record 45 of Set 12 | petatlan
# Processing Record 46 of Set 12 | brainerd
# Processing Record 47 of Set 12 | gaoyou
# Processing Record 48 of Set 12 | eyl
# Processing Record 49 of Set 12 | divnogorsk
# Processing Record 50 of Set 12 | nisia floresta
# Processing Record 1 of Set 13 | kununurra
# Processing Record 2 of Set 13 | zambezi
# Processing Record 3 of Set 13 | adrar
# Processing Record 4 of Set 13 | moa
# Processing Record 5 of Set 13 | manicore
# Processing Record 6 of Set 13 | darmstadt
# Processing Record 7 of Set 13 | pudozh
# Processing Record 8 of Set 13 | sisimiut
# Processing Record 9 of Set 13 | cockburn town
# Processing Record 10 of Set 13 | ribeira grande
# Processing Record 11 of Set 13 | rexburg
# Processing Record 12 of Set 13 | kama
# Processing Record 13 of Set 13 | linjiang
# Processing Record 14 of Set 13 | borogontsy
# Processing Record 15 of Set 13 | dolgorukovo
# Processing Record 16 of Set 13 | hajdunanas
# Processing Record 17 of Set 13 | havoysund
# Processing Record 18 of Set 13 | altay
# Processing Record 19 of Set 13 | cururupu
# Processing Record 20 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 13 | cam ranh
# Processing Record 22 of Set 13 | warri
# Processing Record 23 of Set 13 | zvornik
# Processing Record 24 of Set 13 | canning
# Processing Record 25 of Set 13 | cayhagan
# Processing Record 26 of Set 13 | acapulco
# Processing Record 27 of Set 13 | kjollefjord
# Processing Record 28 of Set 13 | puerto escondido
# Processing Record 29 of Set 13 | yemelyanovo
# Processing Record 30 of Set 13 | alice springs
# Processing Record 31 of Set 13 | bandarbeyla
# Processing Record 32 of Set 13 | kosh-agach
# Processing Record 33 of Set 13 | paamiut
# Processing Record 34 of Set 13 | malard
# Processing Record 35 of Set 13 | porechye-rybnoye
# Processing Record 36 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 37 of Set 13 | mount isa
# Processing Record 38 of Set 13 | nyurba
# Processing Record 39 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 13 | kulhudhuffushi
# Processing Record 41 of Set 13 | hobyo
# Processing Record 42 of Set 13 | lumeje
# Processing Record 43 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 13 | bukoba
# Processing Record 45 of Set 13 | chicama
# Processing Record 46 of Set 13 | tiarei
# Processing Record 47 of Set 13 | ojuelos de jalisco
# Processing Record 48 of Set 13 | maniitsoq
# Processing Record 49 of Set 13 | luena
# Processing Record 50 of Set 13 | acarau
# Processing Record 1 of Set 14 | coahuayana
# Processing Record 2 of Set 14 | requena
# Processing Record 3 of Set 14 | nazare
# Processing Record 4 of Set 14 | kumbo
# Processing Record 5 of Set 14 | xining
# Processing Record 6 of Set 14 | flinders
# Processing Record 7 of Set 14 | jackson
# Processing Record 8 of Set 14 | port hawkesbury
# Processing Record 9 of Set 14 | akyab
# Processing Record 10 of Set 14 | esperance
# Processing Record 11 of Set 14 | conde
# Processing Record 12 of Set 14 | novokayakent
# Processing Record 13 of Set 14 | fort saint james
# Processing Record 14 of Set 14 | pinega
# Processing Record 15 of Set 14 | luderitz
# Processing Record 16 of Set 14 | kamen-rybolov
# Processing Record 17 of Set 14 | beringovskiy
# Processing Record 18 of Set 14 | la paz
# Processing Record 19 of Set 14 | rio grande
# Processing Record 20 of Set 14 | bulungu
# Processing Record 21 of Set 14 | matehuala
# Processing Record 22 of Set 14 | santo antonio do monte
# Processing Record 23 of Set 14 | eresos
# Processing Record 24 of Set 14 | dunedin
# Processing Record 25 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 26 of Set 14 | san isidro
# Processing Record 27 of Set 14 | waipawa
# Processing Record 28 of Set 14 | balabac
# Processing Record 29 of Set 14 | wanning
# Processing Record 30 of Set 14 | itoman
# Processing Record 31 of Set 14 | omboue
# Processing Record 32 of Set 14 | evensk
# Processing Record 33 of Set 14 | west bay
# Processing Record 34 of Set 14 | lashio
# Processing Record 35 of Set 14 | paso de los toros
# Processing Record 36 of Set 14 | whitehorse
# Processing Record 37 of Set 14 | narok
# Processing Record 38 of Set 14 | tres arroyos
# Processing Record 39 of Set 14 | udarnyy
# Processing Record 40 of Set 14 | aksarka
# Processing Record 41 of Set 14 | ciras
# City not found. Skipping...
# Processing Record 42 of Set 14 | vzmorye
# Processing Record 43 of Set 14 | alamosa
# Processing Record 44 of Set 14 | sualkuchi
# Processing Record 45 of Set 14 | nuuk
# Processing Record 46 of Set 14 | reyes
# Processing Record 47 of Set 14 | palmer
# Processing Record 48 of Set 14 | kuandian
# Processing Record 49 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 50 of Set 14 | champoton
# Processing Record 1 of Set 15 | ubatuba
# Processing Record 2 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 15 | chiang klang
# Processing Record 4 of Set 15 | ibra
# Processing Record 5 of Set 15 | srandakan
# Processing Record 6 of Set 15 | khasan
# Processing Record 7 of Set 15 | antofagasta
# Processing Record 8 of Set 15 | san jose
# Processing Record 9 of Set 15 | toulepleu
# City not found. Skipping...
# Processing Record 10 of Set 15 | tabuk
# Processing Record 11 of Set 15 | birao
# Processing Record 12 of Set 15 | viedma
# Processing Record 13 of Set 15 | bonnyville
# Processing Record 14 of Set 15 | los llanos de aridane
# Processing Record 15 of Set 15 | dehloran
# Processing Record 16 of Set 15 | sakakah
# Processing Record 17 of Set 15 | atchison
# Processing Record 18 of Set 15 | jizan
# Processing Record 19 of Set 15 | hachinohe
# Processing Record 20 of Set 15 | hirado
# Processing Record 21 of Set 15 | saint anthony
# Processing Record 22 of Set 15 | nakasongola
# Processing Record 23 of Set 15 | monte gordo
# Processing Record 24 of Set 15 | laurel
# Processing Record 25 of Set 15 | tsabong
# Processing Record 26 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 15 | ashtian
# Processing Record 28 of Set 15 | el sauce
# Processing Record 29 of Set 15 | rognan
# Processing Record 30 of Set 15 | bairiki
# Processing Record 31 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 15 | tadine
# Processing Record 33 of Set 15 | novikovo
# Processing Record 34 of Set 15 | larsnes
# Processing Record 35 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 15 | inta
# Processing Record 37 of Set 15 | matamoros
# Processing Record 38 of Set 15 | san joaquin
# Processing Record 39 of Set 15 | beloha
# Processing Record 40 of Set 15 | nicoya
# Processing Record 41 of Set 15 | uruacu
# Processing Record 42 of Set 15 | batagay
# Processing Record 43 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 15 | dawei
# Processing Record 45 of Set 15 | powell river
# Processing Record 46 of Set 15 | jacqueville
# Processing Record 47 of Set 15 | khandyga
# Processing Record 48 of Set 15 | batemans bay
# Processing Record 49 of Set 15 | carupano
# Processing Record 50 of Set 15 | inirida
# Processing Record 1 of Set 16 | burns lake
# Processing Record 2 of Set 16 | boa vista
# Processing Record 3 of Set 16 | kandi
# Processing Record 4 of Set 16 | mogadishu
# Processing Record 5 of Set 16 | najran
# Processing Record 6 of Set 16 | rafsanjan
# Processing Record 7 of Set 16 | milkovo
# Processing Record 8 of Set 16 | sao miguel do araguaia
# Processing Record 9 of Set 16 | laukaa
# Processing Record 10 of Set 16 | lianzhou
# Processing Record 11 of Set 16 | arivonimamo
# Processing Record 12 of Set 16 | petilia policastro
# Processing Record 13 of Set 16 | kenai
# Processing Record 14 of Set 16 | issoire
# Processing Record 15 of Set 16 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 16 | brejo da madre de deus
# Processing Record 17 of Set 16 | vanimo
# Processing Record 18 of Set 16 | mattru
# Processing Record 19 of Set 16 | qandala
# Processing Record 20 of Set 16 | aginskoye
# Processing Record 21 of Set 16 | sao jose da coroa grande
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Huarmey -10.0681  -78.1522     71.46        78          93
# 1               Ushuaia -54.8000  -68.3000     57.20        41          40
# 2                Atuona  -9.8000 -139.0333     78.15        80           9
# 3               Mataura -46.1927  168.8643     60.01        81          99
# 4                Barrow  71.2906 -156.7887      1.40        78           1
# 5             Fairbanks  64.8378 -147.7164     21.00        78          75
# 6               Margate  51.3813    1.3862     34.00        81          25
# 7  Nova Olinda Do Norte  -3.8881  -59.0942     73.71        95          28
# 8                  Kang -23.6752   22.7876     71.76        28          94
# 9             Caravelas -17.7125  -39.2481     73.40        86          27
#
#    Wind Speed Current Description Country                 Date
# 0        5.88     overcast clouds      PE  2021-01-24 03:38:45
# 1       16.11    scattered clouds      AR  2021-01-24 03:38:45
# 2       17.83           clear sky      PF  2021-01-24 03:38:45
# 3       21.00     overcast clouds      NZ  2021-01-24 03:38:46
# 4       16.11                haze      US  2021-01-24 03:34:39
# 5        3.22       broken clouds      US  2021-01-24 03:38:46
# 6       14.74    scattered clouds      GB  2021-01-24 03:38:46
# 7        1.83    scattered clouds      BR  2021-01-24 03:38:46
# 8        7.65     overcast clouds      BW  2021-01-24 03:38:46
# 9        2.28    scattered clouds      BR  2021-01-24 03:38:32

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head()
# Out:
#       City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Huarmey      PE -10.0681  -78.1522     71.46        78          93
# 1  Ushuaia      AR -54.8000  -68.3000     57.20        41          40
# 2   Atuona      PF  -9.8000 -139.0333     78.15        80           9
# 3  Mataura      NZ -46.1927  168.8643     60.01        81          99
# 4   Barrow      US  71.2906 -156.7887      1.40        78           1
#
#    Wind Speed Current Description
# 0        5.88     overcast clouds
# 1       16.11    scattered clouds
# 2       17.83           clear sky
# 3       21.00     overcast clouds
# 4       16.11                haze

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
